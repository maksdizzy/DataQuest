# %% [markdown]
# # Goal
# Practice using some of the techniques we learned to analyze startup investments from Crunchbase.com.
#
# ## [Dataset](https://github.com/datahoarder/crunchbase-october-2013/blob/master/crunchbase-investments.csv)

# %%
import pandas as pd
import numpy as np
import sqlite3

# %% [markdown]
# Because the data set contains over 50,000 rows, we'll read the data set into dataframes using 5,000 row chunks to ensure that each chunk consumes much less than 10 megabytes of memory.

# %%
cb_iter = pd.read_csv('crunchbase-investments.csv', chunksize=5000, encoding='ISO-8859-1')

# %%
for chunk in cb_iter:
    size = chunk.memory_usage(deep='True').sum() / (1024 * 1024)
    print(size)
# Out:
# 5.579195022583008
# 5.528186798095703
# 5.535004615783691
# 5.528162956237793
# 5.5243072509765625
# 5.553412437438965
# 5.531391143798828
# 5.509613037109375
# 5.396090507507324
# 4.63945198059082
# 2.663668632507324

# %% [markdown]
# Across all of the chunks, let's become familiar with:
#  - Each column's missing value counts
#  - Each column's memory footprint
#  - The total memory footprint of all of the chunks combined
#  - Which column(s) we can drop because they aren't useful for analysis

# %% [markdown]
# Missing value counts

# %%
cb_iter = pd.read_csv('crunchbase-investments.csv', chunksize=5000, encoding='ISO-8859-1')
missing = []
for chunk in cb_iter:
    missing.append(chunk.isnull().sum())

combined_missing = pd.concat(missing)
final_missing = combined_missing.groupby(combined_missing.index).sum().sort_values()
print(final_missing)
# Out:
# company_country_code          1
# company_name                  1
# company_permalink             1
# company_region                1
# investor_region               2
# investor_permalink            2
# investor_name                 2
# funded_quarter                3
# funded_at                     3
# funded_month                  3
# funded_year                   3
# funding_round_type            3
# company_state_code          492
# company_city                533
# company_category_code       643
# raised_amount_usd          3599
# investor_country_code     12001
# investor_city             12480
# investor_state_code       16809
# investor_category_code    50427
# dtype: int64

# %% [markdown]
# Columns memory footprint (in Mb)

# %%
cb_iter = pd.read_csv('crunchbase-investments.csv', chunksize=5000, encoding='ISO-8859-1')
memory = []
for chunk in cb_iter:
    memory.append(chunk.memory_usage(deep=True))

combined_memory = pd.concat(memory)
final_memory = combined_memory.groupby(combined_memory.index).sum().sort_values(ascending=False) / (1024 * 1024)
print(final_memory)
# Out:
# investor_permalink        4.749821
# company_permalink         3.869808
# investor_name             3.734270
# company_name              3.424955
# funded_at                 3.378091
# company_city              3.343512
# company_category_code     3.262619
# company_region            3.253541
# funding_round_type        3.252704
# investor_region           3.238946
# funded_month              3.226837
# funded_quarter            3.226837
# company_country_code      3.025223
# company_state_code        2.962161
# investor_city             2.751430
# investor_country_code     2.524654
# investor_state_code       2.361876
# investor_category_code    0.593590
# raised_amount_usd         0.403366
# funded_year               0.403366
# Index                     0.000877
# dtype: float64

# %% [markdown]
# Total memory footprint (in Mb)

# %%
cb_iter = pd.read_csv('crunchbase-investments.csv', chunksize=5000, encoding='ISO-8859-1')
size = 0
for chunk in cb_iter:
    size += chunk.memory_usage(deep='True').sum() / (1024 * 1024)
print(size)
# Out:
# 56.988484382629395

# %% [markdown]
# #### Drop columns those contain links (investor_permalink, company_permalink) or contain too much missing values (investor_category_code). Also we can drop columns funded_month funded_quarter and funded_year because we have funded_at column that fully covers them

# %%
drop_cols = ['investor_permalink', 'company_permalink', 'investor_category_code', 'funded_month', 'funded_quarter', 'funded_year']
keep_cols = chunk.columns.drop(drop_cols)

# %%
keep_cols.tolist
# Out:
# <bound method Index.tolist of Index(['company_name', 'company_category_code', 'company_country_code',
#        'company_state_code', 'company_region', 'company_city', 'investor_name',
#        'investor_country_code', 'investor_state_code', 'investor_region',
#        'investor_city', 'funding_round_type', 'funded_at',
#        'raised_amount_usd'],
#       dtype='object')>

# %% [markdown]
# ### Selecting Data Types
# Let's first determine which columns shift types across chunks. Note that we only lay the groundwork for this step.

# %%
col_types = {}
cb_iter = pd.read_csv('crunchbase-investments.csv', chunksize=5000, encoding='ISO-8859-1', usecols=keep_cols)
for chunk in cb_iter:
    for col in chunk.columns:
        if col not in col_types:
            col_types[col] = [str(chunk[col].dtype)]
        else:
            if str(chunk[col].dtype) not in col_types[col]:
                col_types[col].append(str(chunk[col].dtype))

# %%
col_types
# Out:
# {'company_category_code': ['object'],
#  'company_city': ['object'],
#  'company_country_code': ['object'],
#  'company_name': ['object'],
#  'company_region': ['object'],
#  'company_state_code': ['object'],
#  'funded_at': ['object'],
#  'funding_round_type': ['object'],
#  'investor_city': ['object', 'float64'],
#  'investor_country_code': ['object', 'float64'],
#  'investor_name': ['object'],
#  'investor_region': ['object'],
#  'investor_state_code': ['object', 'float64'],
#  'raised_amount_usd': ['float64']}

# %%
to_be_converted = []

for col in col_types:
    if len(col_types[col]) > 1:
        print('{}: '.format(col), col_types[col])
        to_be_converted.append(col)
# Out:
# investor_state_code:  ['object', 'float64']
# investor_country_code:  ['object', 'float64']
# investor_city:  ['object', 'float64']

# %%
chunk
# Out:
#                   company_name company_category_code company_country_code  \
# 50000                  NuORDER               fashion                  USA
# 50001                   ChaCha           advertising                  USA
# 50002                  Binfire              software                  USA
# 50003                  Binfire              software                  USA
# 50004            Unified Color              software                  USA
# 50005                 HItviews           advertising                  USA
# 50006               LockerDome                social                  USA
# 50007                ThirdLove             ecommerce                  USA
# 50008                    Hakia                search                  USA
# 50009               bookacoach                sports                  USA
# 50010             LocalCircles                social                  USA
# 50011                Graphdive             analytics                  USA
# 50012                   Ribbon             ecommerce                  USA
# 50013            Dokkankom.com             ecommerce                  USA
# 50014                  Lookery                   web                  USA
# 50015             TrustDegrees                   web                  USA
# 50016                  Altavoz           games_video                  USA
# 50017                  EdSurge             education                  USA
# 50018              FullContact            enterprise                  USA
# 50019               Rapt Media            enterprise                  USA
# 50020                 Humanoid              software                  USA
# 50021                 Runscope                   web                  USA
# 50022                   Adzerk           advertising                  USA
# 50023                  Adaptly           advertising                  USA
# 50024                     Lore             education                  USA
# 50025              Tasted Menu           hospitality                  USA
# 50026         Lua Technologies                mobile                  USA
# 50027               Blue Apron           hospitality                  USA
# 50028                   ChatID                mobile                  USA
# 50029  Breakthrough Behavioral                health                  USA
# ...                        ...                   ...                  ...
# 52840                   Meddik                health                  USA
# 52841               Blue Apron           hospitality                  USA
# 52842                   ChatID                mobile                  USA
# 52843  Breakthrough Behavioral                health                  USA
# 52844                    Plaid              software                  USA
# 52845                 PokitDok                mobile                  USA
# 52846                Fitocracy                   web                  USA
# 52847                   Square                mobile                  USA
# 52848                  MixRank           advertising                  USA
# 52849                Socialcam                mobile                  USA
# 52850                   Nuzzel                  news                  USA
# 52851                ThirdLove             ecommerce                  USA
# 52852                    MXD3D                   web                  USA
# 52853                    MXD3D                   web                  USA
# 52854                  Verious                mobile                  USA
# 52855               Identified             analytics                  USA
# 52856              HaulerDeals               fashion                  USA
# 52857            When You Wish             nonprofit                  USA
# 52858                 Farmeron             analytics                  USA
# 52859      Theraclone Sciences               biotech                  USA
# 52860                SimpleGeo           advertising                  USA
# 52861                  Open Me             ecommerce                  USA
# 52862       Comprehend Systems            enterprise                  USA
# 52863                 Payoneer                 other                  USA
# 52864                 Outbrain                   web                  USA
# 52865            Garantia Data            enterprise                  USA
# 52866               DudaMobile                mobile                  USA
# 52867               SiteBrains              software                  USA
# 52868       Comprehend Systems            enterprise                  USA
# 52869              SmartThings                mobile                  USA
#
#       company_state_code      company_region         company_city  \
# 50000                 CA         Los Angeles       West Hollywood
# 50001                 IN        Indianapolis               Carmel
# 50002                 FL         Bocat Raton          Bocat Raton
# 50003                 FL         Bocat Raton          Bocat Raton
# 50004                 CA              SF Bay  South San Frnacisco
# 50005                 NY            New York        New York City
# 50006                 MO         Saint Louis            St. Louis
# 50007                 CA              SF Bay        San Francisco
# 50008                NaN                 TBD                  NaN
# 50009                 IN        Indianapolis         Indianapolis
# 50010                 CA              SF Bay          Santa Clara
# 50011                 CA              SF Bay           Menlo Park
# 50012                 CA              SF Bay        San Francisco
# 50013                 NY            New York             new york
# 50014                 CA              SF Bay        San Francisco
# 50015                 NY             Kenmore              Kenmore
# 50016                 DC       Washington DC           Washington
# 50017                 CA              SF Bay           Burlingame
# 50018                 CO              Denver               Denver
# 50019                 CO              Denver              Boulder
# 50020                 CA              SF Bay        San Francisco
# 50021                 CA              SF Bay        San Francisco
# 50022                 NC      Raleigh-Durham               Durham
# 50023                 NY            New York             New York
# 50024                 NY            New York             New York
# 50025                 MA              Boston               Boston
# 50026                 NY            New York             New York
# 50027                 NY            New York             Brooklyn
# 50028                 NY            New York             New York
# 50029                 CA              SF Bay         Redwood City
# ...                  ...                 ...                  ...
# 52840                 NY            New York             New York
# 52841                 NY            New York             Brooklyn
# 52842                 NY            New York             New York
# 52843                 CA              SF Bay         Redwood City
# 52844                 CA              SF Bay        San Francisco
# 52845                 CA              SF Bay           Menlo Park
# 52846                 NY            New York             New York
# 52847                 CA              SF Bay        San Francisco
# 52848                 CA              SF Bay        San Francisco
# 52849                 CA  Santa Clara County   Santa Clara County
# 52850                 CA              SF Bay        San Francisco
# 52851                 CA              SF Bay        San Francisco
# 52852                 CA              SF Bay        San Francisco
# 52853                 CA              SF Bay        San Francisco
# 52854                 CA              SF Bay           San Carlos
# 52855                 CA              SF Bay        San Francisco
# 52856                 CA         Los Angeles          Los Angeles
# 52857                 CA         Los Angeles       Marina Del Rey
# 52858                 CA              SF Bay        Mountain View
# 52859                 WA             Seattle              Seattle
# 52860                 CA              SF Bay        San Francisco
# 52861                 CA         Los Angeles          Los Angeles
# 52862                 CA              SF Bay            Palo Alto
# 52863                 NY            New York             New York
# 52864                 NY            New York        New York City
# 52865                 CA              SF Bay          Santa Clara
# 52866                 CA              SF Bay            Palo Alto
# 52867                 CA              SF Bay        San Francisco
# 52868                 CA              SF Bay            Palo Alto
# 52869                 DC             unknown          Minneapolis
#
#           investor_name  investor_country_code  investor_state_code  \
# 50000   Mortimer Singer                    NaN                  NaN
# 50001   Morton Meyerson                    NaN                  NaN
# 50002       Moshe Ariel                    NaN                  NaN
# 50003       Moshe Ariel                    NaN                  NaN
# 50004   Mr. Andrew Oung                    NaN                  NaN
# 50005  multiple parties                    NaN                  NaN
# 50006  multiple parties                    NaN                  NaN
# 50007       Munjal Shah                    NaN                  NaN
# 50008       Murat Vargi                    NaN                  NaN
# 50009       Myles Grote                    NaN                  NaN
# 50010      Nadir Godrej                    NaN                  NaN
# 50011    Naguib Sawiris                    NaN                  NaN
# 50012    Naguib Sawiris                    NaN                  NaN
# 50013       Namek Zu'bi                    NaN                  NaN
# 50014         Nana Shin                    NaN                  NaN
# 50015     Nancy Barrett                    NaN                  NaN
# 50016    Nancy Jacobsen                    NaN                  NaN
# 50017   Nancy Peretsman                    NaN                  NaN
# 50018      Nancy Pierce                    NaN                  NaN
# 50019      Nancy Pierce                    NaN                  NaN
# 50020      Nat Friedman                    NaN                  NaN
# 50021      Nat Friedman                    NaN                  NaN
# 50022        Nat Turner                    NaN                  NaN
# 50023        Nat Turner                    NaN                  NaN
# 50024        Nat Turner                    NaN                  NaN
# 50025        Nat Turner                    NaN                  NaN
# 50026        Nat Turner                    NaN                  NaN
# 50027        Nat Turner                    NaN                  NaN
# 50028        Nat Turner                    NaN                  NaN
# 50029        Nat Turner                    NaN                  NaN
# ...                 ...                    ...                  ...
# 52840     Zach Weinberg                    NaN                  NaN
# 52841     Zach Weinberg                    NaN                  NaN
# 52842     Zach Weinberg                    NaN                  NaN
# 52843     Zach Weinberg                    NaN                  NaN
# 52844     Zach Weinberg                    NaN                  NaN
# 52845      Zach Zeitlin                    NaN                  NaN
# 52846    Zachary Aarons                    NaN                  NaN
# 52847     Zachary Bogue                    NaN                  NaN
# 52848     Zachary Bogue                    NaN                  NaN
# 52849     Zachary Bogue                    NaN                  NaN
# 52850     Zachary Bogue                    NaN                  NaN
# 52851     Zachary Bogue                    NaN                  NaN
# 52852        Zaid Ayoub                    NaN                  NaN
# 52853        Zaid Ayoub                    NaN                  NaN
# 52854         Zain Khan                    NaN                  NaN
# 52855          Zao Yang                    NaN                  NaN
# 52856          Zaw Thet                    NaN                  NaN
# 52857      Zelda Marzec                    NaN                  NaN
# 52858    Zeljko Mataija                    NaN                  NaN
# 52859     Zenyaku Kogyo                    NaN                  NaN
# 52860        Ziv Navoth                    NaN                  NaN
# 52861        Ziver Birg                    NaN                  NaN
# 52862         Zod Nazem                    NaN                  NaN
# 52863       Zohar Gilon                    NaN                  NaN
# 52864       Zohar Gilon                    NaN                  NaN
# 52865       Zohar Gilon                    NaN                  NaN
# 52866       Zohar Gilon                    NaN                  NaN
# 52867      zohar israel                    NaN                  NaN
# 52868   Zorba Lieberman                    NaN                  NaN
# 52869      Zorik Gordon                    NaN                  NaN
#
#       investor_region  investor_city funding_round_type   funded_at  \
# 50000         unknown            NaN           series-a  2012-10-01
# 50001         unknown            NaN           series-b  2007-10-01
# 50002         unknown            NaN              angel  2008-04-18
# 50003         unknown            NaN              angel  2010-01-01
# 50004         unknown            NaN              angel  2010-01-01
# 50005         unknown            NaN              angel  2007-11-29
# 50006         unknown            NaN              angel  2012-04-17
# 50007         unknown            NaN           series-a  2012-12-01
# 50008         unknown            NaN           series-a  2006-11-01
# 50009         unknown            NaN              angel  2012-11-01
# 50010         unknown            NaN              angel  2012-09-01
# 50011         unknown            NaN              angel  2012-10-04
# 50012         unknown            NaN           series-a  2013-02-05
# 50013         unknown            NaN              angel  2011-10-10
# 50014         unknown            NaN              angel  2008-02-07
# 50015         unknown            NaN              angel  2011-06-09
# 50016         unknown            NaN              angel  2012-09-11
# 50017         unknown            NaN              angel  2012-08-29
# 50018         unknown            NaN           series-b  2012-07-09
# 50019         unknown            NaN           series-a  2013-01-23
# 50020         unknown            NaN              angel  2010-12-01
# 50021         unknown            NaN              angel  2013-05-22
# 50022         unknown            NaN              angel  2011-07-12
# 50023         unknown            NaN           series-a  2011-04-18
# 50024         unknown            NaN              angel  2011-06-27
# 50025         unknown            NaN              angel  2011-05-01
# 50026         unknown            NaN           series-a  2012-08-01
# 50027         unknown            NaN           series-a  2013-02-19
# 50028         unknown            NaN              angel  2012-01-01
# 50029         unknown            NaN              angel  2012-08-13
# ...               ...            ...                ...         ...
# 52840         unknown            NaN              angel  2012-05-24
# 52841         unknown            NaN           series-a  2013-02-19
# 52842         unknown            NaN              angel  2012-01-01
# 52843         unknown            NaN              angel  2012-08-13
# 52844         unknown            NaN           series-a  2013-09-19
# 52845         unknown            NaN              angel  2012-07-12
# 52846         unknown            NaN              angel  2011-09-01
# 52847         unknown            NaN           series-a  2009-11-01
# 52848         unknown            NaN           series-a  2011-11-18
# 52849         unknown            NaN              angel  2012-04-30
# 52850         unknown            NaN            venture  2012-11-15
# 52851         unknown            NaN           series-a  2012-12-01
# 52852         unknown            NaN              angel  2012-01-01
# 52853         unknown            NaN              angel  2011-01-01
# 52854         unknown            NaN              angel  2011-05-30
# 52855         unknown            NaN           series-b  2012-06-05
# 52856         unknown            NaN              angel  2012-10-31
# 52857         unknown            NaN           series-a  2011-02-01
# 52858         unknown            NaN              angel  2010-10-01
# 52859         unknown            NaN           series-b  2013-03-25
# 52860         unknown            NaN              other  2009-11-10
# 52861         unknown            NaN              angel  2013-08-01
# 52862         unknown            NaN           series-a  2013-07-11
# 52863         unknown            NaN           series-a  2005-01-01
# 52864         unknown            NaN           series-b  2009-02-11
# 52865         unknown            NaN           series-a  2012-08-08
# 52866         unknown            NaN          series-c+  2013-04-08
# 52867         unknown            NaN              angel  2010-08-01
# 52868         unknown            NaN           series-a  2013-07-11
# 52869         unknown            NaN           series-a  2012-12-04
#
#        raised_amount_usd
# 50000          3060000.0
# 50001         12000000.0
# 50002           500000.0
# 50003           750000.0
# 50004                NaN
# 50005           485000.0
# 50006           300000.0
# 50007          5600000.0
# 50008         16000000.0
# 50009                NaN
# 50010                NaN
# 50011          1000000.0
# 50012          1630000.0
# 50013            30000.0
# 50014           900000.0
# 50015             8000.0
# 50016           150000.0
# 50017           400000.0
# 50018          7000000.0
# 50019          2288803.0
# 50020          1100000.0
# 50021          1100000.0
# 50022           650000.0
# 50023          2000000.0
# 50024          1000000.0
# 50025                NaN
# 50026          2500000.0
# 50027          3000000.0
# 50028                NaN
# 50029           900000.0
# ...                  ...
# 52840           750000.0
# 52841          3000000.0
# 52842                NaN
# 52843           900000.0
# 52844          2800000.0
# 52845          1300000.0
# 52846           250000.0
# 52847         10000000.0
# 52848          1500000.0
# 52849                NaN
# 52850          1700000.0
# 52851          5600000.0
# 52852           300000.0
# 52853           300000.0
# 52854           800000.0
# 52855         21000000.0
# 52856          1250000.0
# 52857          1500000.0
# 52858            15000.0
# 52859          8000000.0
# 52860           195000.0
# 52861                NaN
# 52862          8400000.0
# 52863          2000000.0
# 52864         12000000.0
# 52865          3800000.0
# 52866         10300000.0
# 52867           350000.0
# 52868          8400000.0
# 52869          3000000.0
#
# [2870 rows x 14 columns]

# %% [markdown]
# Convert these columns to object type and total check memory footprint:
#  - investor_state_code:  ['object', 'float64']
#  - investor_country_code:  ['object', 'float64']
#  - investor_city:  ['object', 'float64']

# %%
cb_iter = pd.read_csv('crunchbase-investments.csv', chunksize=5000, encoding='ISO-8859-1', usecols=keep_cols)
size = 0
for chunk in cb_iter:
    chunk[to_be_converted] = chunk[to_be_converted].astype('str')
    size += chunk.memory_usage(deep='True').sum() / (1024 * 1024)
print(size)
# Out:
# 42.561177253723145

# %% [markdown]
# ### Load dataset to Database

# %%
conn = sqlite3.connect('cb.db')

# %%
cb_iter = pd.read_csv('crunchbase-investments.csv', chunksize=5000, encoding='ISO-8859-1', usecols=keep_cols)
for chunk in cb_iter:
    chunk[to_be_converted] = chunk[to_be_converted].astype('str')
    chunk.to_sql("crunchbase", conn, if_exists='append', index=False)

# %%
# !ls -l --block-size=M  cb.db
# Out:
# -rw-r--r-- 1 dq dq 13M Oct 15 06:18 cb.db

# %%
db = pd.read_sql("Select * From crunchbase", conn)

# %%
db
# Out:
#                           company_name company_category_code  \
# 0                             AdverCar           advertising
# 1                           LaunchGram                  news
# 2                                 uTaP             messaging
# 3                             ZoopShop              software
# 4                             eFuneral                   web
# 5                                Tackk                   web
# 6                             Acclaimd             analytics
# 7                             Acclaimd             analytics
# 8                             ToVieFor             ecommerce
# 9                             OHK Labs                sports
# 10                              Lovely           real_estate
# 11                        peerTransfer               finance
# 12                            spotdock                   web
# 13                   Fisker Automotive            automotive
# 14                   Fisker Automotive            automotive
# 15                      MetroFlats.com                travel
# 16                            MesoCoat              nanotech
# 17                           Trilliant              hardware
# 18                        Power Assure       network_hosting
# 19                           Trilliant              hardware
# 20                           ECOtality             cleantech
# 21                              Evalve               biotech
# 22                              Ovalis               biotech
# 23              Alvine Pharmaceuticals               biotech
# 24                    Avaxia Biologics               biotech
# 25              AuraSense Therapeutics               biotech
# 26                        LibraryThing                   web
# 27                           HelioVolt             cleantech
# 28     Airband Communications Holdings                mobile
# 29                                Xand              software
# ...                                ...                   ...
# 52840                           Meddik                health
# 52841                       Blue Apron           hospitality
# 52842                           ChatID                mobile
# 52843          Breakthrough Behavioral                health
# 52844                            Plaid              software
# 52845                         PokitDok                mobile
# 52846                        Fitocracy                   web
# 52847                           Square                mobile
# 52848                          MixRank           advertising
# 52849                        Socialcam                mobile
# 52850                           Nuzzel                  news
# 52851                        ThirdLove             ecommerce
# 52852                            MXD3D                   web
# 52853                            MXD3D                   web
# 52854                          Verious                mobile
# 52855                       Identified             analytics
# 52856                      HaulerDeals               fashion
# 52857                    When You Wish             nonprofit
# 52858                         Farmeron             analytics
# 52859              Theraclone Sciences               biotech
# 52860                        SimpleGeo           advertising
# 52861                          Open Me             ecommerce
# 52862               Comprehend Systems            enterprise
# 52863                         Payoneer                 other
# 52864                         Outbrain                   web
# 52865                    Garantia Data            enterprise
# 52866                       DudaMobile                mobile
# 52867                       SiteBrains              software
# 52868               Comprehend Systems            enterprise
# 52869                      SmartThings                mobile
#
#       company_country_code company_state_code         company_region  \
# 0                      USA                 CA                 SF Bay
# 1                      USA                 CA                 SF Bay
# 2                      USA               None  United States - Other
# 3                      USA                 OH               Columbus
# 4                      USA                 OH              Cleveland
# 5                      USA                 OH              Cleveland
# 6                      USA                 OH               Columbus
# 7                      USA                 OH               Columbus
# 8                      USA                 NY               New York
# 9                      USA                 FL             Palm Beach
# 10                     USA                 CA                 SF Bay
# 11                     USA                 MA                 Boston
# 12                     USA                 NY               New York
# 13                     USA                 CA            Los Angeles
# 14                     USA                 CA            Los Angeles
# 15                     USA                 NJ            Cedar Grove
# 16                     USA                 OH              Cleveland
# 17                     USA                 CA                 SF Bay
# 18                     USA                 CA                 SF Bay
# 19                     USA                 CA                 SF Bay
# 20                     USA                 CA                 SF Bay
# 21                     USA                 CA                 SF Bay
# 22                     USA                 CA                 SF Bay
# 23                     USA                 CA                 SF Bay
# 24                     USA                 MA                 Boston
# 25                     USA                 IL                Chicago
# 26                     USA                 ME               Portland
# 27                     USA                 TX                 Austin
# 28                     USA                 TX                 Dallas
# 29                     USA                 NY               New York
# ...                    ...                ...                    ...
# 52840                  USA                 NY               New York
# 52841                  USA                 NY               New York
# 52842                  USA                 NY               New York
# 52843                  USA                 CA                 SF Bay
# 52844                  USA                 CA                 SF Bay
# 52845                  USA                 CA                 SF Bay
# 52846                  USA                 NY               New York
# 52847                  USA                 CA                 SF Bay
# 52848                  USA                 CA                 SF Bay
# 52849                  USA                 CA     Santa Clara County
# 52850                  USA                 CA                 SF Bay
# 52851                  USA                 CA                 SF Bay
# 52852                  USA                 CA                 SF Bay
# 52853                  USA                 CA                 SF Bay
# 52854                  USA                 CA                 SF Bay
# 52855                  USA                 CA                 SF Bay
# 52856                  USA                 CA            Los Angeles
# 52857                  USA                 CA            Los Angeles
# 52858                  USA                 CA                 SF Bay
# 52859                  USA                 WA                Seattle
# 52860                  USA                 CA                 SF Bay
# 52861                  USA                 CA            Los Angeles
# 52862                  USA                 CA                 SF Bay
# 52863                  USA                 NY               New York
# 52864                  USA                 NY               New York
# 52865                  USA                 CA                 SF Bay
# 52866                  USA                 CA                 SF Bay
# 52867                  USA                 CA                 SF Bay
# 52868                  USA                 CA                 SF Bay
# 52869                  USA                 DC                unknown
#
#              company_city                             investor_name  \
# 0           San Francisco                         1-800-FLOWERS.COM
# 1           Mountain View                               10Xelerator
# 2                    None                               10Xelerator
# 3                columbus                               10Xelerator
# 4               Cleveland                               10Xelerator
# 5               Cleveland                               10Xelerator
# 6                Columbus                               10Xelerator
# 7                Columbus                               10Xelerator
# 8                New York  2010 NYU Stern Business Plan Competition
# 9              Boca Raton                           22Hundred Group
# 10          San Francisco                                     3taps
# 11                 Boston                                  500 Hats
# 12                    NYC                              9mmedia, LLC
# 13                 Irvine                              A123 Systems
# 14                 Irvine                              A123 Systems
# 15            Cedar Grove                            AA Investments
# 16                 Euclid                                    Abakan
# 17           Redwood City                                       ABB
# 18            Santa Clara                                       ABB
# 19           Redwood City                                       ABB
# 20          San Francisco                                       ABB
# 21             Menlo Park                               Abbott Labs
# 22          Mountain View                               Abbott Labs
# 23             San Carlos                                    AbbVie
# 24              Lexington                                    AbbVie
# 25               Evanston                                    AbbVie
# 26               Portland                                  AbeBooks
# 27                 Austin                             Abengoa Solar
# 28                 Dallas                             ABRY Partners
# 29              Hawthorne                             ABRY Partners
# ...                   ...                                       ...
# 52840            New York                             Zach Weinberg
# 52841            Brooklyn                             Zach Weinberg
# 52842            New York                             Zach Weinberg
# 52843        Redwood City                             Zach Weinberg
# 52844       San Francisco                             Zach Weinberg
# 52845          Menlo Park                              Zach Zeitlin
# 52846            New York                            Zachary Aarons
# 52847       San Francisco                             Zachary Bogue
# 52848       San Francisco                             Zachary Bogue
# 52849  Santa Clara County                             Zachary Bogue
# 52850       San Francisco                             Zachary Bogue
# 52851       San Francisco                             Zachary Bogue
# 52852       San Francisco                                Zaid Ayoub
# 52853       San Francisco                                Zaid Ayoub
# 52854          San Carlos                                 Zain Khan
# 52855       San Francisco                                  Zao Yang
# 52856         Los Angeles                                  Zaw Thet
# 52857      Marina Del Rey                              Zelda Marzec
# 52858       Mountain View                            Zeljko Mataija
# 52859             Seattle                             Zenyaku Kogyo
# 52860       San Francisco                                Ziv Navoth
# 52861         Los Angeles                                Ziver Birg
# 52862           Palo Alto                                 Zod Nazem
# 52863            New York                               Zohar Gilon
# 52864       New York City                               Zohar Gilon
# 52865         Santa Clara                               Zohar Gilon
# 52866           Palo Alto                               Zohar Gilon
# 52867       San Francisco                              zohar israel
# 52868           Palo Alto                           Zorba Lieberman
# 52869         Minneapolis                              Zorik Gordon
#
#       investor_country_code investor_state_code  investor_region  \
# 0                       USA                  NY         New York
# 1                       USA                  OH         Columbus
# 2                       USA                  OH         Columbus
# 3                       USA                  OH         Columbus
# 4                       USA                  OH         Columbus
# 5                       USA                  OH         Columbus
# 6                       USA                  OH         Columbus
# 7                       USA                  OH         Columbus
# 8                       nan                 nan          unknown
# 9                       nan                 nan          unknown
# 10                      USA                  CA           SF Bay
# 11                      USA                  CA           SF Bay
# 12                      nan                 nan          unknown
# 13                      USA                  MA           Boston
# 14                      USA                  MA           Boston
# 15                      BMU                 nan  Bermuda - Other
# 16                      USA                  FL            Miami
# 17                      CHE                 nan           Zurich
# 18                      CHE                 nan           Zurich
# 19                      CHE                 nan           Zurich
# 20                      CHE                 nan           Zurich
# 21                      USA                  IL          Chicago
# 22                      USA                  IL          Chicago
# 23                      USA                  IL          Chicago
# 24                      USA                  IL          Chicago
# 25                      USA                  IL          Chicago
# 26                      CAN                 nan         Victoria
# 27                      ESP                 nan          Sevilla
# 28                      USA                  MA           Boston
# 29                      USA                  MA           Boston
# ...                     ...                 ...              ...
# 52840                   nan                 nan          unknown
# 52841                   nan                 nan          unknown
# 52842                   nan                 nan          unknown
# 52843                   nan                 nan          unknown
# 52844                   nan                 nan          unknown
# 52845                   nan                 nan          unknown
# 52846                   nan                 nan          unknown
# 52847                   nan                 nan          unknown
# 52848                   nan                 nan          unknown
# 52849                   nan                 nan          unknown
# 52850                   nan                 nan          unknown
# 52851                   nan                 nan          unknown
# 52852                   nan                 nan          unknown
# 52853                   nan                 nan          unknown
# 52854                   nan                 nan          unknown
# 52855                   nan                 nan          unknown
# 52856                   nan                 nan          unknown
# 52857                   nan                 nan          unknown
# 52858                   nan                 nan          unknown
# 52859                   nan                 nan          unknown
# 52860                   nan                 nan          unknown
# 52861                   nan                 nan          unknown
# 52862                   nan                 nan          unknown
# 52863                   nan                 nan          unknown
# 52864                   nan                 nan          unknown
# 52865                   nan                 nan          unknown
# 52866                   nan                 nan          unknown
# 52867                   nan                 nan          unknown
# 52868                   nan                 nan          unknown
# 52869                   nan                 nan          unknown
#
#        investor_city funding_round_type   funded_at  raised_amount_usd
# 0           New York           series-a  2012-10-30          2000000.0
# 1           Columbus              other  2012-01-23            20000.0
# 2           Columbus              other  2012-01-01            20000.0
# 3           Columbus              angel  2012-02-15            20000.0
# 4           Columbus              other  2011-09-08            20000.0
# 5           Columbus              other  2012-02-01            20000.0
# 6           Columbus              angel  2012-06-01            20000.0
# 7           Columbus              angel  2012-08-07            70000.0
# 8                nan              angel  2010-04-01            75000.0
# 9                nan              angel  2011-09-01           100000.0
# 10     San Francisco           series-a  2012-10-01          2000000.0
# 11         Palo Alto              angel  2010-10-28          1100000.0
# 12               nan              angel  2012-01-10           600000.0
# 13         Watertown           series-a  2010-05-01        189000000.0
# 14         Watertown            venture  2011-02-22        150000000.0
# 15               nan              angel  2010-08-18                NaN
# 16             Miami            venture  2009-12-14                NaN
# 17            Zurich           series-b  2010-07-15        106000000.0
# 18            Zurich            venture  2010-09-20          1500000.0
# 19            Zurich            venture  2010-12-21                NaN
# 20            Zurich            venture  2011-01-09         10000000.0
# 21       Des Plaines          series-c+  2007-11-27         60000000.0
# 22       Des Plaines           series-b  2007-01-30          6600000.0
# 23           Chicago     private-equity  2013-05-14         70000000.0
# 24           Chicago           series-b  2013-06-07         11500000.0
# 25           Chicago           series-b  2013-07-31                NaN
# 26          Victoria           series-a  2006-05-16                NaN
# 27           Sevilla           series-b  2007-10-23        101000000.0
# 28            Boston            venture  2011-08-11         20000000.0
# 29            Boston              other  2013-09-12        200000000.0
# ...              ...                ...         ...                ...
# 52840            nan              angel  2012-05-24           750000.0
# 52841            nan           series-a  2013-02-19          3000000.0
# 52842            nan              angel  2012-01-01                NaN
# 52843            nan              angel  2012-08-13           900000.0
# 52844            nan           series-a  2013-09-19          2800000.0
# 52845            nan              angel  2012-07-12          1300000.0
# 52846            nan              angel  2011-09-01           250000.0
# 52847            nan           series-a  2009-11-01         10000000.0
# 52848            nan           series-a  2011-11-18          1500000.0
# 52849            nan              angel  2012-04-30                NaN
# 52850            nan            venture  2012-11-15          1700000.0
# 52851            nan           series-a  2012-12-01          5600000.0
# 52852            nan              angel  2012-01-01           300000.0
# 52853            nan              angel  2011-01-01           300000.0
# 52854            nan              angel  2011-05-30           800000.0
# 52855            nan           series-b  2012-06-05         21000000.0
# 52856            nan              angel  2012-10-31          1250000.0
# 52857            nan           series-a  2011-02-01          1500000.0
# 52858            nan              angel  2010-10-01            15000.0
# 52859            nan           series-b  2013-03-25          8000000.0
# 52860            nan              other  2009-11-10           195000.0
# 52861            nan              angel  2013-08-01                NaN
# 52862            nan           series-a  2013-07-11          8400000.0
# 52863            nan           series-a  2005-01-01          2000000.0
# 52864            nan           series-b  2009-02-11         12000000.0
# 52865            nan           series-a  2012-08-08          3800000.0
# 52866            nan          series-c+  2013-04-08         10300000.0
# 52867            nan              angel  2010-08-01           350000.0
# 52868            nan           series-a  2013-07-11          8400000.0
# 52869            nan           series-a  2012-12-04          3000000.0
#
# [52870 rows x 14 columns]

# %% [markdown]
# ### Use the pandas SQLite workflow to answer the following questions:
#  - What proportion of the total amount of funds did the top 10% raise? What about the top 1%? Compare these values to the proportions the bottom 10% and bottom 1% raised.
#  - Which category of company attracted the most investments?
#  - Which investor contributed the most money (across all startups)?
#  - Which investors contributed the most money per startup?
#  - Which funding round was the most popular? Which was the least popular?

# %%
cur = conn.cursor()

# %% [markdown]
# #### What proportion of the total amount of funds did the top 10% raise?

# %%
cur.execute("""SELECT SUM(raised_amount_usd) FROM crunchbase""")
total_funds = cur.fetchall()

# %%
cur.execute("""SELECT SUM(raised_amount_usd) FROM (SELECT * FROM crunchbase ORDER BY raised_amount_usd DESC LIMIT 4927)""")
top_ten_funds = cur.fetchall()

# %%
top_ten_funds[0][0] / total_funds[0][0]
# Out:
# 0.4985610752406796

# %%
cur.execute("""SELECT SUM(raised_amount_usd) FROM (SELECT * FROM crunchbase ORDER BY raised_amount_usd DESC LIMIT 493)""")
top_one_funds = cur.fetchall()

# %%
top_one_funds[0][0] / total_funds[0][0]
# Out:
# 0.19299778563809128

# %% [markdown]
# #### What about the top 1%? Compare these values to the proportions the bottom 10% and bottom 1% raised.

# %%
bottom_ten_funds = pd.read_sql("SELECT raised_amount_usd FROM crunchbase ORDER BY 1", conn)

# %%
bottom_ten_funds = bottom_ten_funds.dropna()

# %%
bottom_ten_funds.head(round(len(bottom_ten_funds) / 10)).sum()[0] / top_ten_funds[0][0]
# Out:
# 0.00527409025208126

# %%
bottom_ten_funds.head(round(len(bottom_ten_funds) / 100)).sum()[0] / top_ten_funds[0][0]
# Out:
# 2.6612958705066928e-05

# %% [markdown]
# #### Which category of company attracted the most investments?

# %%
cur.execute("""
            SELECT company_category_code, SUM(raised_amount_usd) FROM crunchbase
            GROUP BY 1
            ORDER BY 2 DESC
            """)
top_categories = cur.fetchmany(10)

# %%
top_categories
# Out:
# [('biotech', 110396423062.0),
#  ('software', 73084516724.0),
#  ('mobile', 64777379752.0),
#  ('cleantech', 52705225028.0),
#  ('enterprise', 45860927273.0),
#  ('web', 40143264989.0),
#  ('medical', 25367105281.0),
#  ('advertising', 25076661879.0),
#  ('ecommerce', 22567220071.0),
#  ('network_hosting', 22419683840.0)]

# %% [markdown]
# #### Which investor contributed the most money (across all startups)?

# %%
cur.execute("""
            SELECT investor_name, SUM(raised_amount_usd) FROM crunchbase
            GROUP BY 1
            ORDER BY 2 DESC
            """)
top_investors = cur.fetchmany(10)

# %%
top_investors
# Out:
# [('Kleiner Perkins Caufield & Byers', 11217826376.0),
#  ('New Enterprise Associates', 9692542344.0),
#  ('Accel Partners', 6472126199.0),
#  ('Goldman Sachs', 6375459000.0),
#  ('Sequoia Capital', 6039402410.0),
#  ('Intel', 5969200000.0),
#  ('Google', 5808800000.0),
#  ('Time Warner', 5730000000.0),
#  ('Comcast', 5669000000.0),
#  ('Greylock Partners', 4960982939.0)]

# %% [markdown]
# #### Which investors contributed the most money per startup?

# %%
cur.execute("""
            SELECT investor_name, SUM(raised_amount_usd) / COUNT(raised_amount_usd) FROM crunchbase
            GROUP BY 1
            ORDER BY 2 DESC
            """)
top_investors_per_company = cur.fetchmany(10)

# %%
top_investors_per_company
# Out:
# [('Marlin Equity Partners', 2600000000.0),
#  ('BrightHouse', 2350000000.0),
#  ('GI Partners', 1050000000.0),
#  ('Sprint Nextel', 833333333.3333334),
#  ('Siemens PLM Software', 750000000.0),
#  ('Comcast', 629888888.8888888),
#  ('Eagle River Holdings', 614250000.0),
#  ('Time Warner', 520909090.90909094),
#  ('Laurel Crown Partners', 450000000.0),
#  ('Intel', 397946666.6666667)]

# %% [markdown]
# #### Which funding round was the most popular? Which was the least popular?

# %%
cur.execute("""
            SELECT funding_round_type, COUNT(funding_round_type) FROM crunchbase
            GROUP BY 1
            ORDER BY 2 DESC
            """)
top_rounds = cur.fetchmany(3)

# %%
top_rounds
# Out:
# [('series-a', 13938), ('series-c+', 10870), ('angel', 8989)]

# %%
cur.execute("""
            SELECT funding_round_type, COUNT(funding_round_type) FROM crunchbase
            GROUP BY 1
            ORDER BY 2
            """)
bottom_rounds = cur.fetchmany(3)

# %%
bottom_rounds
# Out:
# [(None, 0), ('crowdfunding', 5), ('post-ipo', 33)]
